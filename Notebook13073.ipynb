# %% [markdown]
# # ***Matplotlib***

# %%
#import numpy as np
#pip install pandas
import matplotlib as plt

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # ***Plot***

# %%
import numpy as np
puntos_x  = np.array([0,4,8,16])
puntos_y =  np.array([6,12,24,48])

plt.plot(puntos_x,puntos_y)
plt.show()

# %%
x1 = np.array([0,1,2,3])
y1 = np.array([3,8,1,10])
x2 = np.array([0,1,2,3])
y2 = np.array([6,2,7,11])

plt.plot(x1,y1,x2,y2)
plt.show()

# %%
y1 = np.array([3,8,1,10])
y2 = np.array([6,2,7,11])

plt.plot(y1)
plt.plot(y2)
plt.show()

# %% [markdown]
# # ***Formato***

# %%
puntos_y = np.array([6,12,24,48])
plt.plot(puntos_y,'o')
plt.show()

# %%
plt.plot(puntos_x,puntos_y,'y')
plt.show()
# Marcador

# 'o'
# '*'
# '.'
# ','
# 'x'
# 'X'
# '+'
# 'P'
# 's'
# 'D'
# 'd'
# 'p'
# 'H'
# 'h'
# 'g'
# 'k'
# 'm'
# 'r'
# 'v'
# 'y'

# %%
plt.plot(puntos_x,puntos_y, '-v')
plt.show()
# Linea
# '-'
# ':'
# '--'
# '-.'
# '-*'
# '-v'

# %%
plt.plot(puntos_x,puntos_y, 'w')
plt.show()
#Color

# 'r'
# 'g'
# 'b'
# 'c'
# 'm'
# 'y'
# 'k'
# 'w'

# %%
plt.plot(puntos_x,puntos_y,'*:c')
plt.show()
# Mix, pointers, lines and color

# %%
plt.plot(puntos_x,puntos_y, 'v--g', ms=8, mec='k', linewidth='2')
plt.show()

# %% [markdown]
# # ***Descripción***

# %%
x = np.array([80,85,90,95,100,105,110,115,120,125])
y = np.array([240,250,260,270,280,290,300,310,320,330])
plt.plot(x,y)

plt.title("Estadisticas Deportivas")
plt.xlabel("Pulso Promedio")
plt.ylabel("Quema de calorias")

plt.show()

# %%
plt.plot(x,y)

font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}

plt.title("Estadisticas deportivas", fontdict=font1)
plt.xlabel("Pulso Promedio", fontdict=font2)
plt.ylabel("Quema de Calorias",fontdict=font2)
plt.show()

# %%
plt.title("Estadisticas Deportivas", loc="left")
plt.xlabel("Pulso Promedio")
plt.ylabel("Quema de Calorias")

plt.plot(x,y)
plt.show()

# %% [markdown]
# # ***Grid***

# %%
x = np.array([80,85,90,95,100,105,110,115,120,125])
y = np.array([240,250,260,270,280,290,300,310,320,330])

plt.title("Estadisticas Deportivas")
plt.xlabel("Pulso Promedio")
plt.ylabel("Quema de Calorias")

plt.plot(x,y)
plt.grid()
plt.show()

# %%
x = np.array([80,85,90,95,100,105,110,115,120,125])
y = np.array([240,250,260,270,280,290,300,310,320,330])

plt.title("Estadisticas Deportivas")
plt.xlabel("Pulso Promedio")
plt.ylabel("Quema de Calorias")

plt.plot(x,y)
plt.grid(axis='x', linestyle='--',linewidth=1)
plt.show()

# %% [markdown]
# # ***Multiples Graficos***
